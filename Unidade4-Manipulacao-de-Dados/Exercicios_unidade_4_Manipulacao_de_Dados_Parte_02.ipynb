# %% [markdown]
# # Awari - Data Science
#
# ## Exercícios Unidade 4 - Parte 2

# %% [markdown]
# Neste Jupyter notebook você irá resolver uma série de exercícios utilizando a linguagem Python e a biblioteca Pandas.
#
# Você utilizará um dataset com dados de jogos de futebol da Europa.
#
# Todo o seu código deve ser executado neste Jupyter Notebook. Por fim, se desejar, revise as respostas com o seu mentor.

# %% [markdown]
# ### Passo 1. Importe o dataset e salve os dados em um dataframe
#
# Os dados estão salvos no arquivo ***datasets/euro2012.csv***.
#
# Salve os dados em uma variável de nome *euro12*.

# %%
import pandas as pd

# %%
euro12 = pd.read_csv('datasets/euro2012.csv', encoding='UTF-8')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 0              0              0                     0  ...          13
# 1              0              0                     0  ...           9
# 2              1              0                     0  ...          10
# 3              0              0                     0  ...          22
# 4              1              0                     0  ...           6
# 5              2              1                     0  ...          10
# 6              1              1                     1  ...          13
# 7              2              0                     0  ...          20
# 8              2              0                     0  ...          12
# 9              0              0                     0  ...           6
# 10             6              0                     0  ...          10
# 11             0              0                     0  ...          17
# 12             2              0                     0  ...          10
# 13             0              1                     0  ...          15
# 14             3              0                     0  ...           8
# 15             0              0                     0  ...          13
#
#     Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  Yellow Cards  \
# 0                  81.3%         41             62         2             9
# 1                  60.1%         53             73         8             7
# 2                  66.7%         25             38         8             4
# 3                  88.1%         43             45         6             5
# 4                  54.6%         36             51         5             6
# 5                  62.6%         63             49        12             4
# 6                  65.1%         67             48        12             9
# 7                  74.1%        101             89        16            16
# 8                  70.6%         35             30         3             5
# 9                  66.7%         48             56         3             7
# 10                 71.5%         73             90        10            12
# 11                 65.4%         43             51        11             6
# 12                 77.0%         34             43         4             6
# 13                 93.8%        102             83        19            11
# 14                 61.6%         35             51         7             7
# 15                 76.5%         48             31         4             5
#
#     Red Cards  Subs on  Subs off  Players Used
# 0           0        9         9            16
# 1           0       11        11            19
# 2           0        7         7            15
# 3           0       11        11            16
# 4           0       11        11            19
# 5           0       15        15            17
# 6           1       12        12            20
# 7           0       18        18            19
# 8           0        7         7            15
# 9           1        7         7            17
# 10          0       14        14            16
# 11          1       10        10            17
# 12          0        7         7            16
# 13          0       17        17            18
# 14          0        9         9            18
# 15          0        9         9            18
#
# [16 rows x 35 columns]

# %% [markdown]
# ### Passo 2. Quantas o tamanho do dataset (linhas e colunas)?

# %%
euro12.shape
# Resposta: O dataset possui 16 linhas e 35 colunas.
# Out:
# (16, 35)

# %% [markdown]
# ### Passo 3. Quantos e quais times participaram do campeonato?

# %%
euro12.Team.unique
# Resposta: Participaram do torneio 15 times, que são: República Tcheca, Dinamarca, Inglaterra, França, Alemanha, Grécia,
# Itália, Holanda, Polônia, Portugal, Irlanda, Rússia, Espanha, Suécia e Ucrânia.
# Out:
# <bound method Series.unique of 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object>

# %% [markdown]
# ### Passo 4. Crie um novo dataframe com as colunas *Team*, *Yellow Cards* e *Red Cards*.

# %%
dicionario = {'Team': euro12['Team'], 'Yellow Cards': euro12['Yellow Cards'], 'Red Cards': euro12['Red Cards']}
dataframe = pd.DataFrame(dicionario)
dataframe
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Passo 5. Ordene os times pela quantidade de cartões amarelos.

# %%
dataframe.sort_values('Yellow Cards')
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 9                Poland             7          1
# 14               Sweden             7          0
# 0               Croatia             9          0
# 6                Greece             9          1
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0

# %% [markdown]
# ### Passo 6. Qual a média de cartões amarelos por time?

# %%
euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# ### Passo 7. Selecione os times que fizeram mais de 6 gols.

# %%
euro12.Team[euro12['Goals'] > 6]
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# ### Passo 8. Quais times que fizeram gol de pênalti?

# %%
euro12.Team[euro12['Penalty goals'] > 0]
# Out:
# 5     Germany
# 6      Greece
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# ### Passo 9. Mostre somente a coluna "Shooting Accuracy" para os times *England*, *Italy* e *Russia*

# %%
euro12[euro12.Team.isin(['England', 'Italy', 'Russia'])][['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ### Passo 10. Qual o time que fez mais gols?

# %%
maximo = euro12['Goals'].max()
euro12[['Team', 'Goals']].loc[euro12['Goals'] == maximo]
# Out:
#      Team  Goals
# 13  Spain     12

# %% [markdown]
# ### Awari -  <a href="https://awari.com.br/"> awari.com.br</a>
